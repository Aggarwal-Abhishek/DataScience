# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('white')
# %matplotlib inline

# %% [markdown]
# ### Data

# %%
columnNames = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('u.data', sep='\t', names=columnNames)
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
movieTitles = pd.read_csv('Movie_Id_Titles')
movieTitles.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
df = pd.merge(df, movieTitles, on='item_id')
df.head()
# Out:
#    user_id  item_id  rating  timestamp             title
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %% [markdown]
# ### EDA

# %%
df.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# They Made Me a Criminal (1939)                5.0
# Marlene Dietrich: Shadow and Light (1996)     5.0
# Saint of Fort Washington, The (1993)          5.0
# Someone Else's America (1995)                 5.0
# Star Kid (1997)                               5.0
# Name: rating, dtype: float64

# %%
df.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# Star Wars (1977)             584
# Contact (1997)               509
# Fargo (1996)                 508
# Return of the Jedi (1983)    507
# Liar Liar (1997)             485
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df.groupby('title')['rating'].mean())
ratings['count'] = pd.DataFrame(df.groupby('title')['rating'].count())
ratings.head()
# Out:
#                              rating  count
# title
# 'Til There Was You (1997)  2.333333      9
# 1-900 (1994)               2.600000      5
# 101 Dalmatians (1996)      2.908257    109
# 12 Angry Men (1957)        4.344000    125
# 187 (1997)                 3.024390     41

# %%
ratings['count'].hist(bins=70)
plt.figure()
ratings['rating'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
ratings
# Out:
#                                          rating  count
# title
# 'Til There Was You (1997)              2.333333      9
# 1-900 (1994)                           2.600000      5
# 101 Dalmatians (1996)                  2.908257    109
# 12 Angry Men (1957)                    4.344000    125
# 187 (1997)                             3.024390     41
# ...                                         ...    ...
# Young Guns II (1990)                   2.772727     44
# Young Poisoner's Handbook, The (1995)  3.341463     41
# Zeus and Roxanne (1997)                2.166667      6
# unknown                                3.444444      9
# Á köldum klaka (Cold Fever) (1994)     3.000000      1
#
# [1664 rows x 2 columns]

# %% [markdown]
# ### Recommending similar movies

# %%
df
# Out:
#         user_id  item_id  rating  timestamp  \
# 0             0       50       5  881250949
# 1           290       50       5  880473582
# 2            79       50       4  891271545
# 3             2       50       5  888552084
# 4             8       50       5  879362124
# ...         ...      ...     ...        ...
# 99998       840     1674       4  891211682
# 99999       655     1640       3  888474646
# 100000      655     1637       3  888984255
# 100001      655     1630       3  887428735
# 100002      655     1641       3  887427810
#
#                                                     title
# 0                                        Star Wars (1977)
# 1                                        Star Wars (1977)
# 2                                        Star Wars (1977)
# 3                                        Star Wars (1977)
# 4                                        Star Wars (1977)
# ...                                                   ...
# ...

# %%
movieMat = df.pivot_table(index='user_id', columns='title', values='rating')
movieMat.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
starwar_rating = movieMat['Star Wars (1977)']
liarliar_rating = movieMat['Liar Liar (1997)']
starwar_rating.head()
# Out:
# user_id
# 0    5.0
# 1    5.0
# 2    5.0
# 3    NaN
# 4    5.0
# Name: Star Wars (1977), dtype: float64

# %%
similarToStarwars = movieMat.corrwith(starwar_rating)
similarToLiarliar = movieMat.corrwith(liarliar_rating)
similarToStarwars
# Out:
# /usr/local/lib/python3.9/site-packages/numpy/lib/function_base.py:2821: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.9/site-packages/numpy/lib/function_base.py:2680: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.9/site-packages/numpy/lib/function_base.py:2821: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.9/site-packages/numpy/lib/function_base.py:2680: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# title
# 'Til There Was You (1997)                0.872872
# 1-900 (1994)                            -0.645497
# 101 Dalmatians (1996)                    0.211132
# 12 Angry Men (1957)                      0.184289
# 187 (1997)                               0.027398
#                                            ...
# ...

# %%
corrStarwars = pd.DataFrame(similarToStarwars, columns=['Correlation'])
corrStarwars.dropna(inplace=True)
corrStarwars.head()
# Out:
#                            Correlation
# title
# 'Til There Was You (1997)     0.872872
# 1-900 (1994)                 -0.645497
# 101 Dalmatians (1996)         0.211132
# 12 Angry Men (1957)           0.184289
# 187 (1997)                    0.027398

# %%
corrStarwars = corrStarwars.join(ratings['count'])
corrStarwars.head()
# Out:
#                            Correlation    rating  count
# title
# 'Til There Was You (1997)     0.872872  2.333333      9
# 1-900 (1994)                 -0.645497  2.600000      5
# 101 Dalmatians (1996)         0.211132  2.908257    109
# 12 Angry Men (1957)           0.184289  4.344000    125
# 187 (1997)                    0.027398  3.024390     41

# %%
corrStarwars[corrStarwars['count']>100].sort_values('Correlation', ascending=False).head()
# Out:
#                                                     Correlation    rating  \
# title
# Star Wars (1977)                                       1.000000  4.359589
# Empire Strikes Back, The (1980)                        0.748353  4.206522
# Return of the Jedi (1983)                              0.672556  4.007890
# Raiders of the Lost Ark (1981)                         0.536117  4.252381
# Austin Powers: International Man of Mystery (1997)     0.377433  3.246154
#
#                                                     count
# title
# Star Wars (1977)                                      584
# Empire Strikes Back, The (1980)                       368
# Return of the Jedi (1983)                             507
# Raiders of the Lost Ark (1981)                        420
# Austin Powers: International Man of Mystery (1997)    130
